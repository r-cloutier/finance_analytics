# %% [markdown]
# # Test short-term investment strategies
#
# Here we'll define some metrics to select stocks for short-term investment and then generate the resulting income that we could have attained as a function of duration of investment and dollar amounts.

# %%
import utility_funcs as utf               # plotting and currency conversion functions
import sp500_data as sp5                  # functions to get sp500 market data
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from yahoo_fin import stock_info as si    # functions to read in ticker time series
import datetime as dt
import pickle, os
# %matplotlib inline

# %% [markdown]
# ## first get S&P 500 market data

# %%
start_date = dt.datetime(2019,1,1)

d = dt.datetime.now()
todays_date = dt.datetime(d.year, d.month, d.day)
end_date = todays_date

# %%
sp500_dict = sp5.get_sp500_timeseries(start_date, end_date, retrieve_new_data=True)    # get time series data from the web
sp500_dict = sp5.compute_fractional_growth(sp500_dict)         # compute the fractional growth of each ticker
sp500_dict = sp5.compute_sp500_fractional_growth(sp500_dict)   # ad hoc calculation of fractional growth of the S&P
# Out:
# 001	A
# 002	AAL
# 003	AAP
# 004	AAPL
# 005	ABBV
# 006	ABC
# 007	ABMD
# 008	ABT
# 009	ACN
# 010	ADBE
# 011	ADI
# 012	ADM
# 013	ADP
# 014	ADS
# 015	ADSK
# 016	AEE
# 017	AEP
# 018	AES
# 019	AFL
# 020	AGN
# 021	AIG
# 022	AIV
# 023	AIZ
# 024	AJG
# 025	AKAM
# 026	ALB
# 027	ALGN
# 028	ALK
# 029	ALL
# 030	ALLE
# 031	ALXN
# 032	AMAT
# 033	AMD
# 034	AME
# 035	AMG
# 036	AMGN
# 037	AMP
# 038	AMT
# 039	AMZN
# 040	ANET
# 041	ANSS
# 042	ANTM
# 043	AON
# 044	AOS
# 045	APA
# 046	APC
# 047	APD
# 048	APH
# 049	APTV
# 050	ARE
# 051	ARNC
# 052	ATO
# 053	ATVI
# 054	AVB
# 055	AVGO
# 056	AVY
# 057	AWK
# 058	AXP
# 059	AZO
# 060	BA
# 061	BAC
# 062	BAX
# 063	BBT
# 064	BBY
# 065	BDX
# 066	BEN
# 067	BF.B
# 068	BHGE
# 069	BIIB
# 070	BK
# 071	BKNG
# 072	BLK
# 073	BLL
# 074	BMY
# 075	BR
# 076	BRK.B
# 077	BSX
# 078	BWA
# 079	BXP
# 080	C
# 081	CAG
# 082	CAH
# 083	CAT
# 084	CB
# 085	CBOE
# 086	CBRE
# 087	CBS
# 088	CCI
# 089	CCL
# 090	CDNS
# 091	CE
# 092	CELG
# 093	CERN
# 094	CF
# 095	CFG
# 096	CHD
# 097	CHRW
# 098	CHTR
# 099	CI
# 100	CINF
# 101	CL
# 102	CLX
# 103	CMA
# 104	CMCSA
# 105	CME
# 106	CMG
# 107	CMI
# 108	CMS
# 109	CNC
# 110	CNP
# 111	COF
# 112	COG
# 113	COO
# 114	COP
# 115	COST
# 116	COTY
# 117	CPB
# 118	CPRI
# 119	CPRT
# 120	CRM
# 121	CSCO
# 122	CSX
# 123	CTAS
# 124	CTL
# 125	CTSH
# 126	CTXS
# 127	CVS
# 128	CVX
# 129	CXO
# 130	D
# 131	DAL
# 132	DE
# 133	DFS
# 134	DG
# 135	DGX
# 136	DHI
# 137	DHR
# 138	DIS
# 139	DISCA
# 140	DISCK
# 141	DISH
# 142	DLR
# 143	DLTR
# 144	DOV
# 145	DOW
# 146	DRE
# 147	DRI
# 148	DTE
# 149	DUK
# 150	DVA
# 151	DVN
# 152	DWDP
# 153	DXC
# 154	EA
# 155	EBAY
# 156	ECL
# 157	ED
# 158	EFX
# 159	EIX
# 160	EL
# 161	EMN
# 162	EMR
# 163	EOG
# 164	EQIX
# 165	EQR
# 166	ES
# 167	ESS
# 168	ETFC
# 169	ETN
# 170	ETR
# 171	EVRG
# 172	EW
# 173	EXC
# 174	EXPD
# 175	EXPE
# 176	EXR
# 177	F
# 178	FANG
# 179	FAST
# 180	FB
# 181	FBHS
# 182	FCX
# 183	FDX
# 184	FE
# 185	FFIV
# 186	FIS
# 187	FISV
# 188	FITB
# 189	FL
# 190	FLIR
# 191	FLR
# 192	FLS
# 193	FLT
# 194	FMC
# 195	FOX
# 196	FOXA
# 197	FRC
# 198	FRT
# 199	FTI
# 200	FTNT
# 201	FTV
# 202	GD
# 203	GE
# 204	GILD
# 205	GIS
# 206	GLW
# 207	GM
# 208	GOOG
# 209	GOOGL
# 210	GPC
# 211	GPN
# 212	GPS
# 213	GRMN
# 214	GS
# 215	GWW
# 216	HAL
# 217	HAS
# 218	HBAN
# 219	HBI
# 220	HCA
# 221	HCP
# 222	HD
# 223	HES
# 224	HFC
# 225	HIG
# 226	HII
# 227	HLT
# 228	HOG
# 229	HOLX
# 230	HON
# 231	HP
# 232	HPE
# 233	HPQ
# 234	HRB
# 235	HRL
# 236	HRS
# 237	HSIC
# 238	HST
# 239	HSY
# 240	HUM
# 241	IBM
# 242	ICE
# 243	IDXX
# 244	IFF
# 245	ILMN
# 246	INCY
# 247	INFO
# 248	INTC
# 249	INTU
# 250	IP
# 251	IPG
# 252	IPGP
# 253	IQV
# 254	IR
# 255	IRM
# 256	ISRG
# 257	IT
# 258	ITW
# 259	IVZ
# 260	JBHT
# 261	JCI
# 262	JEC
# 263	JEF
# 264	JKHY
# 265	JNJ
# 266	JNPR
# 267	JPM
# 268	JWN
# 269	K
# 270	KEY
# 271	KEYS
# 272	KHC
# 273	KIM
# 274	KLAC
# 275	KMB
# 276	KMI
# 277	KMX
# 278	KO
# 279	KR
# 280	KSS
# 281	KSU
# 282	L
# 283	LB
# 284	LEG
# 285	LEN
# 286	LH
# 287	LIN
# 288	LKQ
# 289	LLL
# 290	LLY
# 291	LMT
# 292	LNC
# 293	LNT
# 294	LOW
# 295	LRCX
# 296	LUV
# 297	LW
# 298	LYB
# 299	M
# 300	MA
# 301	MAA
# 302	MAC
# 303	MAR
# 304	MAS
# 305	MAT
# 306	MCD
# 307	MCHP
# 308	MCK
# 309	MCO
# 310	MDLZ
# 311	MDT
# 312	MET
# 313	MGM
# 314	MHK
# 315	MKC
# 316	MLM
# 317	MMC
# 318	MMM
# 319	MNST
# 320	MO
# 321	MOS
# 322	MPC
# 323	MRK
# 324	MRO
# 325	MS
# 326	MSCI
# 327	MSFT
# 328	MSI
# 329	MTB
# 330	MTD
# 331	MU
# 332	MXIM
# 333	MYL
# 334	NBL
# 335	NCLH
# 336	NDAQ
# 337	NEE
# 338	NEM
# 339	NFLX
# 340	NI
# 341	NKE
# 342	NKTR
# 343	NLSN
# 344	NOC
# 345	NOV
# 346	NRG
# 347	NSC
# 348	NTAP
# 349	NTRS
# 350	NUE
# 351	NVDA
# 352	NWL
# 353	NWS
# 354	NWSA
# 355	O
# 356	OKE
# 357	OMC
# 358	ORCL
# 359	ORLY
# 360	OXY
# 361	PAYX
# 362	PBCT
# 363	PCAR
# 364	PEG
# 365	PEP
# 366	PFE
# 367	PFG
# 368	PG
# 369	PGR
# 370	PH
# 371	PHM
# 372	PKG
# 373	PKI
# 374	PLD
# 375	PM
# 376	PNC
# 377	PNR
# 378	PNW
# 379	PPG
# 380	PPL
# 381	PRGO
# 382	PRU
# 383	PSA
# 384	PSX
# 385	PVH
# 386	PWR
# 387	PXD
# 388	PYPL
# 389	QCOM
# 390	QRVO
# 391	RCL
# 392	RE
# 393	REG
# 394	REGN
# 395	RF
# 396	RHI
# 397	RHT
# 398	RJF
# 399	RL
# 400	RMD
# 401	ROK
# 402	ROL
# 403	ROP
# 404	ROST
# 405	RSG
# 406	RTN
# 407	SBAC
# 408	SBUX
# 409	SCHW
# 410	SEE
# 411	SHW
# 412	SIVB
# 413	SJM
# 414	SLB
# 415	SLG
# 416	SNA
# 417	SNPS
# 418	SO
# 419	SPG
# 420	SPGI
# 421	SRE
# 422	STI
# 423	STT
# 424	STX
# 425	STZ
# 426	SWK
# 427	SWKS
# 428	SYF
# 429	SYK
# 430	SYMC
# 431	SYY
# 432	T
# 433	TAP
# 434	TDG
# 435	TEL
# 436	TFX
# 437	TGT
# 438	TIF
# 439	TJX
# 440	TMK
# 441	TMO
# 442	TPR
# 443	TRIP
# 444	TROW
# 445	TRV
# 446	TSCO
# 447	TSN
# 448	TSS
# 449	TTWO
# 450	TWTR
# 451	TXN
# 452	TXT
# 453	UA
# 454	UAA
# 455	UAL
# 456	UDR
# 457	UHS
# 458	ULTA
# 459	UNH
# 460	UNM
# 461	UNP
# 462	UPS
# 463	URI
# 464	USB
# 465	UTX
# 466	V
# 467	VAR
# 468	VFC
# 469	VIAB
# 470	VLO
# 471	VMC
# 472	VNO
# 473	VRSK
# 474	VRSN
# 475	VRTX
# 476	VTR
# 477	VZ
# 478	WAB
# 479	WAT
# 480	WBA
# 481	WCG
# 482	WDC
# 483	WEC
# 484	WELL
# 485	WFC
# 486	WHR
# 487	WLTW
# 488	WM
# 489	WMB
# 490	WMT
# 491	WRK
# 492	WU
# 493	WY
# 494	WYNN
# 495	XEC
# 496	XEL
# 497	XLNX
# 498	XOM
# 499	XRAY
# 500	XRX
# 501	XYL
# 502	YUM
# 503	ZBH
# 504	ZION
# 505	ZTS

# %%
utf.plot_timeseries_SP500(sp500_dict)

# %% [markdown]
# ## define some metric to identify promising stocks

# %%
# this metric compares the slope of a stock's fractional growth over a a given date range to the same slope for 
# the S&P 500. Let's see if stocks with larger slopes continue to perform in the proceeding months over which money
# would be invested

def compare_ticker_slope(ticker, start_date, end_date, pltt=True):
    '''Compare the slope of a ticker over a date range to the SP500.'''
    # compute sp500 slope over that date range
    inrange = (sp500_dict['AAPL'].index >= start_date.date()) & (sp500_dict['AAPL'].index <= end_date.date())
    xarr, yarr = sp500_dict['delta_t_days'][inrange], sp500_dict['sp500_frac_growth_mean'][inrange]
    sp500_slope = (yarr[-1] - yarr[0]) / (xarr[-1] - xarr[0])
    
    # compute ticker slope
    ticker_dict = {ticker : si.get_data(ticker, start_date=start_date, end_date=end_date)}
    ticker_dict = sp5.compute_fractional_growth(ticker_dict)
    tarr = ticker_dict[ticker].index.map(mdates.date2num)
    xarr, yarr = tarr - tarr.min(), ticker_dict[ticker]['frac_growth']
    ticker_slope = (yarr[-1] - yarr[0]) / (xarr[-1] - xarr[0])
    
    # plot time series
    if pltt:
        utf.plot_timeseries_SP500(sp500_dict, ticker_dict)
        plt.show()
    
    # define metric
    slope_ratio = ticker_slope / sp500_slope
    
    return sp500_slope, ticker_slope, slope_ratio

# %% [markdown]
# ## define function to compute how much we gain

# %%
def calculate_gain_fixed_sell(ticker, amount_to_invest_CAD, buy_date, sell_date, ticker_in_USD=True,
                              transaction_fee_CAD=9.99):
    '''Consider a hypothetical situation in which a certain amount of a stock is purchased on a certain date in the 
    past. What would the return on investment have been after some amount of time?'''
    # convert from USD to CAD?
    convert = utf.USD2CAD(1) if ticker_in_USD else 1.
    
    # calculate cost of purchase
    df = si.get_data(ticker, start_date=buy_date, end_date=sell_date)
    buy_price_per_share_CAD = df['open'][0]*convert
    Nshares_to_buy = int(np.floor((amount_to_invest_CAD - transaction_fee_CAD) / buy_price_per_share_CAD))
    buy_price_total_CAD = Nshares_to_buy * buy_price_per_share_CAD + transaction_fee_CAD
    assert buy_price_total_CAD <= amount_to_invest_CAD
    
    # get return
    sell_price_per_share_CAD = df['open'][-1]*convert
    return_total_CAD = Nshares_to_buy * sell_price_per_share_CAD - transaction_fee_CAD
    gain = return_total_CAD - buy_price_total_CAD
    
    return buy_price_per_share_CAD, buy_price_total_CAD, sell_price_per_share_CAD, return_total_CAD, gain

# %%
p = calculate_gain_fixed_sell('CM', 100, date_of_buy, todays_date, ticker_in_USD=False)
p
# Out:
# (79.91999816894531,
#  89.90999816894531,
#  83.4000015258789,
#  73.41000152587891,
#  -16.499996643066396)

# %% [markdown]
# ## run the simulation on some stocks of interest
#
# Let's consider a list of stocks that we are interested in and let's see how well we perform if we select stocks based on this metric, invest some funds, and then sell after a fixed amount of time.

# %%
# define potential stocks of interest
tickers = ['AC.TO','CTC.TO','BBD-B.TO','ACHC','RCI-B.TO']
Ntick = len(tickers)

# %%
# compute slope metrics
date_of_buy = dt.datetime(2019,4,1)
sp500_slopes, ticker_slopes, slope_ratios = np.zeros(Ntick), np.zeros(Ntick), np.zeros(Ntick)
for i in range(Ntick):
    p = compare_ticker_slope(tickers[i], start_date, date_of_buy, pltt=False)
    sp500_slopes[i], ticker_slopes[i], slope_ratios[i] = p

# %%
#
# Out:
# array([1.55986876, 0.32234547, 1.30456197, 0.84252396, 0.26171162])
